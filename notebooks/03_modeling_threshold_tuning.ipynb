# %%
import sys
sys.path.append('../src')

from data_loader import load_telco_data
from preprocess import preprocess_data
from train_model import train_logreg
from metrics import evaluate_thresholds
from sklearn.metrics import accuracy_score

# Load and preprocess
df = load_telco_data("../data/telco_churn.csv")
X, y, scaler = preprocess_data(df)

# Train model
model, X_test, y_test = train_logreg(X, y)

# Train model
model, X_test, y_test = train_logreg(X, y)

y_pred = model.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print("Model accuracy:", acc)


# Evaluate thresholds
thresholds, precision_vals, recall_vals, f1_vals = evaluate_thresholds(
    model, X_test, y_test, save_dir="../plots"
)

# Display best threshold
import numpy as np
best_t = thresholds[np.argmax(f1_vals)]
best_t
# Out:
# Model accuracy: 0.8055358410220014
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 26
#      22 print("Model accuracy:", acc)
#      25 # Evaluate thresholds
# ---> 26 thresholds, precision_vals, recall_vals, f1_vals = evaluate_thresholds(
#      27     model, X_test, y_test, save_dir="../plots"
#      28 )
#      30 # Display best threshold
#      31 import numpy as np
#
# File d:\ML-project-4\notebooks\../src\metrics.py:28, in evaluate_thresholds(model, X_test, y_test, save_dir)
#      26 plt.ylabel("Precision")
#      27 plt.title("Threshold vs Precision")
# ---> 28 plt.savefig(f"{save_dir}/threshold_vs_precision.png")
#      29 plt.close()
#      31 plt.figure()
#
# File d:\ML-project-4\.venv\Lib\site-packages\matplotlib\pyplot.py:1250, in savefig(*args, **kwargs)
#    1247 fig = gcf()
# ...
